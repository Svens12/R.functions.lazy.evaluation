# %%
mysum=function(y,x=2,w=5) {
    z=x+y+w
    return (z)
}

# %%
mysum(3)
# Out:
# [1] 10

# %%
mysum=function(x,y,w) {
    z=x+y+w
    return (z)
}

# %%
mysum(1,2,3)
# Out:
# [1] 6

# %%
mysum=function(x,y,w) {
    z=x+y
    return (z)
}

# %%
mysum(10,20)
# Out:
# [1] 30
